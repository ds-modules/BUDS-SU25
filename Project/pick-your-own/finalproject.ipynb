# %%
# run this cell
import pandas as pd
from datascience import *
import numpy as np
import math
import matplotlib.pyplot as plt
# feel free to add any other imports you might need to complete your project
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# # BUDS 2024 Final Project

# %% [markdown]
# ### Background Knowledge + Finding Your Data Set
#
# By this point, you should be in your groups for the final project! You may not necessarily be working on the same data set as your group members, but that's okay! In practice, even though you may not be doing the same exact task as another Data Scientist, it can still be beneficial to work with others (spending long hours just coding and analyzing data alone can feel isolating at times).
#
# If you haven't already found the exact Data Set(s) you want to work with, please spend some time doing that now! There are plenty of resources to find data. A lot of times, simply typing what you're interested in and the words "data set" into the search engine of your choice will yield some good results. There are also some websites that you can visit to find different data sets. Try checking out these websites if you're ever looking for a data set to use:
# - [Kaggle](https://www.kaggle.com/datasets)
# - [Google Data Set Search](https://datasetsearch.research.google.com/)
# - [U.S. Government Data](https://data.gov/)

# %% [markdown]
# If you recall our discussion about the Data Science Life Cycle, we discovered that there are two distinct entry points: you can either start off by creating the question you want to answer and then proceed to find the data needed to answer it, or you can start with the data and then create your question based on the information that you have available. In terms of your Final Project, it is entirely up to you which path you choose to follow! If you haven't done so already, please make a copy of this [Individual Exploration document](https://docs.google.com/document/d/1t6Brz8SRR4ON3bGAJxVgTmGZoR8GqTYb/edit) to guide you through the question formulation part of your project.
#
# In addition to forming your question, please take some time to note your background knowledge on the data that you are trying to analyze. What do you already know about your topic? What are some of the things that experts on your topic are saying? Also, it would be a good idea to note where your data is coming from. Is the source reputable and trustworthy? Why would the person(s) uploading this data do so? Do they have any motives or ideas that they are trying to push? Ensruing that your data is authentic is arguably the most important part of any data analysis - what would be the point of the hours of hard work to answer your question if the data you're using isn't accurate? Spend about an hour performing this Individual Exploration, and feel free to talk through things with your group members and ask your facilitators any questions you may have!

# %% [markdown]
# ### Uploading Your Data Set to Jupyter
#
# Once you have settled on your question and found a reputable data set(s) that will help you answer it, let one of the facilitators know so that they can look over your work so far. After receiving approval, you can actually download your data set and begin the next steps in the Data Science Life Cycle!
#
# Wherever you have found the data set that you want to work with, you should have the option to download it to your computer. Locate the download button on whichever website you're on and click on it. All of the following screenshots will be showing the process for downloading a data set from Kaggle, but the general process should be similar for other websites as well.

# %% [markdown]
# ![buds24_finalproj_01.jpg](attachment:2e4acb94-ac0f-4e10-bf11-4ecd86ef37ca.jpg)

# %% [markdown]
# Once you have downloaded the data set onto your computer, check to see if it has bee downloaded as a .csv file. If yes, then you're all set for the next part! There might be a possibility that your file was downloaded as a .zip file though. If this is the case, locate the .zip file in your local directory (wherever you normally find your files) and double-click on it to unzip the file. This should reveal a .csv file with the data that you want.

# %% [markdown]
# ![buds24_finalproj_02.jpg](attachment:5c44e2bf-b864-4761-a7f5-e033fa242a21.jpg)

# %% [markdown]
# ![buds24_finalproj_03.jpg](attachment:e000ba30-c583-4762-b2d3-76792794f194.jpg)

# %% [markdown]
# ![buds24_finalproj_04.jpg](attachment:298dd898-7366-4ce6-97c5-79ea3df8b933.jpg)

# %% [markdown]
# This is how my file showed up after double-clicking on the .zip package. Depending on the format, your .csv file might be included in a folder with some other files too. Just locate the file(s) the you want to work with and ensure they are in the .csv format. If they aren't, go back to the website that you downloaded it from and see if there are any options to download the file as a .csv (there should be an option for this, but if not, please notify a facilitator so they can assist).

# %% [markdown]
# # The Data Science Life Cycle
# ## 1. Formulating a Question or Problem <a id='section 1'></a>

# %% [markdown]
# ### Exploring Your Data Set

# %% [markdown]
# Now that your Data Set has been uploaded to Jupyter, you can turn it into a table and start doing what you need to do in order to try and answer your question! To focus your attention back onto your task, please rewrite the question that you want to answer below. There's also space for you to update your question if you feel like that needs to happen as you are going through your data, and for you to keep track of exactly what data you need in order to answer your question.

# %% [markdown]
# **Original Question(s):** *here*
#
#
# **Updated Question(s):** *here*
#
#
# **Data you would need:** *here*

# %% [markdown]
# In the cell below, please assign the variable my_file_string to a string with the name of your .csv file that you uploaded to the data folder in Jupyter (include the .csv part in the string too!). After running the cell, you should see a nice table with all the data that you need for your project!

# %%
my_file_string = ...
my_data = Table().read_table("data/" + my_file_string)

# %% [markdown]
# ## 2. Acquiring and Cleaning Data <a id='section 2'></a>

# %% [markdown]
# <div class="alert alert-info">
# <b>Question:</b> It's important to evalute our data source. What do you know about the source? What motivations do they have for collecting this data? What data is missing?
#    </div>

# %% [markdown]
# *Insert answer here*

# %% [markdown]
# <div class="alert alert-info">
# <b>Question:</b> We want to learn more about the dataset. First, how many total rows are in this table? What does each row represent?
#
#    </div>

# %% [markdown]
# *Insert answer here*

# %%
total_rows = ...
total_rows

# %% [markdown]
# <div class="alert alert-info">
# <b>Question:</b> We want to learn more about the dataset. What are the column labels of this dataset?
#
#    </div>

# %%
column_labels = ...
columns_labels

# %% [markdown]
# ## 3. Conducting Exploratory Data Analysis <a id='section 3'></a>

# %% [markdown]
# Visualizations help us to understand what the dataset is telling us. We will be using bar charts, scatter plots, and line plots to try to answer questions like the following:

# %% [markdown]
# <div class="alert alert-info">
# <b>Question:</b> Make 5 Visualizations on the data.
#    </div>

# %% [markdown]
# ## 4. Using Prediction and Inference to Draw Conclusions <a id='section 4'></a>

# %% [markdown]
# <div class="alert alert-info">
# <b>Question:</b> Tell us something interesting about this data.
#    </div>

# %% [markdown]
# *Insert answer here*

# %% [markdown]
# ## 5. The Data Science Life Cycle: Your Take <a id='section 5'></a>

# %% [markdown]
# Now, formulate and answer some questions you have about the data. Follow the data science life cycle, and be sure to document the different patterns you notice. Take note of what issues also appear and how they can be resolved (e.g., collecting more data).
